# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
from PIL import Image
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.layers import Dense,Conv2D,Rescaling,MaxPooling2D,Flatten,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import pathlib 

data_dir =  pathlib.Path('dataset')

image_count = len(list(data_dir.glob('*/*.jpg')))

# %%
beagle = list(data_dir.glob('Beagle/*'))

beagle_count = len(beagle)

Image.open(str(beagle[2]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=162x108>

# %%
# train_datagen = ImageDataGenerator(
#     rescale=1./255,           # Normalize pixel values
#     rotation_range=40,        # Random rotation
#     width_shift_range=0.2,    # Horizontal shift
#     height_shift_range=0.2,   # Vertical shift
#     shear_range=0.2,          # Shear transformation
#     zoom_range=0.2,           # Random zoom
#     horizontal_flip=True,     # Random horizontal flip
#     fill_mode='nearest',      # Fill missing pixels
#     validation_split=0.2      # Set aside 20% of data for validation
# )

# %%
batch_size =32
img_height = 180
img_width = 180

# %%
# creating a dataset 

# generates a dataset from image files in a directory
train_ds = train_datagen.flow_from_directory(data_dir,
                                        subset="training",
                                        seed=123,
                                        class_mode='categorical',
                                        target_size=(img_height,img_width),
                                        batch_size=batch_size,
                                        shuffle=True                              
)

# creating validation dataset
val_ds = train_datagen.flow_from_directory(data_dir,
                                        subset="validation",
                                        class_mode='categorical',
                                        seed=123,
                                        target_size=(img_height,img_width),
                                        batch_size=batch_size,
                                        shuffle=False
)
# Out:
# Found 775 images belonging to 10 classes.
# Found 192 images belonging to 10 classes.

# %%
# generates a dataset from image files in a directory
train_ds = image_dataset_from_directory(data_dir,
                                        validation_split=0.2,
                                        subset="training",
                                        seed=123,
                                        image_size=(img_height,img_width),
                                        batch_size=batch_size)
# Out:
# Found 967 files belonging to 10 classes.
# Using 774 files for training.

# %%
# creating validation dataset
val_ds = image_dataset_from_directory(data_dir,
                                      validation_split=0.2,
                                      subset='validation',
                                      seed=123,
                                      image_size=(img_height,img_width),
                                      batch_size=batch_size)
# Out:
# Found 967 files belonging to 10 classes.
# Using 193 files for validation.

# %%
class_names= train_ds.class_names
# class_names = list(train_ds.class_indices.keys())
class_names
# Out:
# ['Beagle',
#  'Boxer',
#  'Bulldog',
#  'Dachshund',
#  'German_Shepherd',
#  'Golden_Retriever',
#  'Labrador_Retriever',
#  'Poodle',
#  'Rottweiler',
#  'Yorkshire_Terrier']

# %%
plt.figure(figsize=(10,10))

#take(1) - used to specify the number of batch to take from your dataset

for images,labels in train_ds.take(1):
    for i in range(9):
        ax =plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis("off")
        plt.show()

# %%
# convert dataset to numpy array
images_list,labels_list = [],[]

for images,labels in train_ds:
    images_list.append(images.numpy().astype('uint8'))
    labels_list.append(labels.numpy().astype('uint8'))

# %%
# converting validation data set
val_images_list,val_labels_list = [],[]

for images,labels in val_ds:
    val_images_list.append(images.numpy().astype('uint8'))
    val_labels_list.append(labels.numpy().astype('uint8'))

# %%
# putting all the batches into a single list
X_train = np.concatenate(images_list, axis=0)
y_train = np.concatenate(labels_list, axis=0)

X_train.shape,y_train.shape
# Out:
# ((774, 180, 180, 3), (774,))

# %%
# putting all the batches into a single list
X_test = np.concatenate(val_images_list, axis=0)
y_test = np.concatenate(val_labels_list, axis=0)

X_test.shape,y_test.shape
# Out:
# ((193, 180, 180, 3), (193,))

# %%
# standardize the data
normalizer = Rescaling(1./255)

X_train_scaled = normalizer(X_train)
X_test_scaled= normalizer(X_test)

# %%
num_classes =10

model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model1=model.fit(X_train_scaled,y_train,epochs=10,batch_size=32,validation_data=(X_test_scaled,y_test))
# Out:
# Epoch 1/10
# 25/25 [==============================] - 17s 649ms/step - loss: 2.2090 - accuracy: 0.2390 - val_loss: 1.7953 - val_accuracy: 0.4715
# Epoch 2/10
# 25/25 [==============================] - 16s 634ms/step - loss: 0.9867 - accuracy: 0.7016 - val_loss: 0.5147 - val_accuracy: 0.8860
# Epoch 3/10
# 25/25 [==============================] - 17s 675ms/step - loss: 0.1656 - accuracy: 0.9548 - val_loss: 0.1973 - val_accuracy: 0.9948
# Epoch 4/10
# 25/25 [==============================] - 17s 678ms/step - loss: 0.0230 - accuracy: 0.9987 - val_loss: 0.0702 - val_accuracy: 0.9948
# Epoch 5/10
# 25/25 [==============================] - 16s 647ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9948
# Epoch 6/10
# 25/25 [==============================] - 15s 621ms/step - loss: 3.9800e-04 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9948
# Epoch 7/10
# 25/25 [==============================] - 16s 637ms/step - loss: 2.5822e-04 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9948
# Epoch 8/10
# 25/25 [==============================] - 16s 658ms/step - loss: 2.1031e-04 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9948
# Epoch 9/10
# 25/25 [==============================] - 16s 661ms/step - loss: 1.6781e-04 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9948
# Epoch 10/10
# 25/25 [==============================] - 16s 630ms/step - loss: 1.4704e-04 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9948

# %%
y_pred=model.predict(X_test_scaled)
# Out:
# 7/7 [==============================] - 0s 47ms/step

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0589 - accuracy: 0.9948
# [0.05894605442881584, 0.9948186278343201]

# %%
def predict_breed(index):
    plt.imshow(X_test_scaled[index])
    plt.title(class_names[np.argmax(y_pred[index])])
    plt.show()

# %%
predict_breed(20)

# %%
plt.figure(figsize=(20,20))
pd.DataFrame(model1.history).plot()
plt.show()
